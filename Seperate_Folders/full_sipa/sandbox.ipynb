# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import ad_functions as adfns
from tqdm import tqdm
import pandas as pd
import numpy as np
import pytesseract
import shutil
import cv2
import os

# %%
adfns.display_four_images("./sipaimages/3", "Sipa 3 Images")
