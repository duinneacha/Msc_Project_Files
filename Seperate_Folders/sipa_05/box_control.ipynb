# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from imutils.perspective import four_point_transform, order_points
from matplotlib import pyplot as plt
import box_function as bf
from imutils import contours
import numpy as np
import argparse
import imutils
import math
import cv2
# Out:
# ad2

# %%
# input_file = "./boxed/5/13.jpg"
input_file = "./manually_cropped/mancrop_5.jpg"
# input_file = "./example/recognize-digits-master/calculator3.jpg"
# input_file = "./example/recognize-digits-master/calculator2.jpg"
# input_file = "./sipaimages/5/14.jpg"
# input_file = "./example/recognize-digits-master/example.jpg"
largest_area = 0
skew = 1

width_adjustment = 1
height_adjustment = 1


(digits, output_image) = bf.get_digits(input_file, skew, largest_area, width_adjustment, height_adjustment)

if digits is not None:
    print(digits)
    bf.show_img(output_image, 5, "Output")
else:
    print("No digits found")
# Out:
# ad2
# cnts_cv: 2
# cnts_cv: 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [56], line 14
#      10 width_adjustment = 1
#      11 height_adjustment = 1
# ---> 14 (digits, output_image) = bf.get_digits(input_file, skew, largest_area, width_adjustment, height_adjustment)
#      16 if digits is not None:
#      17     print(digits)
#
# File d:\MTU\_Project_Grunt_Work\Seperate_Folders\sipa_05\box_function.py:79, in get_digits(input_file, skew, largest_area, width_adjustment, height_adjustment)
#      73 print("cnts_cv:", len(cnts_cv))
#      75 # somehow contourArea can not be used to sort the calculator rounded rectange area
#      76 # cnts = sorted(cnts, key=cv2.contourArea, reverse=True)
#      77
#      78 # use boundingRect instead of contourArea
# ---> 79 cnts_cv, rcts = sort_contours_bound_rect(cnts_cv, reverse=True)
#      81 displayCnt = None
# ...
